# %% [markdown]
# ## Topics: String Functions, Type Casting, Input, Operators, and If-Else (Nested)

# %% [markdown]
# ### 1. Ek string variable banayein jisme aapka full name ho, aur usse poora CAPITAL letters mein print karein.

# %%
full_name = "Muhammad Minhaj"

print(full_name.upper())
# Out:
# MUHAMMAD MINHAJ

# %% [markdown]
# ### 2. User se unka fav fruit poochiye aur uski length (kitne characters hain) print karein.

# %%
fav_fruit = input("Enter your favourite fruit")
print(len(fav_fruit))
# Out:
# Enter your favourite fruit mango
# 5

# %% [markdown]
# ### 3. Ek sentence likhiye 'Python is fun' aur 'fun' ko 'awesome' se replace karke print karein.

# %%
sentence = "Python is fun"
sentence = sentence.replace("fun", "Awesome")
print(sentence)
# Out:
# Python is Awesome

# %% [markdown]
# ### 4. Check karein ke string 'Hello World' mein 'World' kaunse index par start hota hai.

# %%
text = "Hello World"
text = text.find('World')
print(text)
# Out:
# 6

# %% [markdown]
# ### 5. User se unka email address lein aur usse hamesha small letters (lowercase) mein convert karke dikhayein.

# %%
email = input("Enter your email")
email = email.lower()
print(email)
# Out:
# Enter your email mAazAFZal@gmail.com
# maazafzal@gmail.com

# %% [markdown]
# ### 6. Ek sentence '   Python Programming   ' banayein aur uske extra spaces (suru aur aakhir ke) remove karein.

# %%
sentence = "      Python Programming   "
sentence = sentence.strip()
print(sentence)
# Out:
# Python Programming

# %% [markdown]
# ### 7. Ek string 'Welcome to coding' mein count karein ke 'o' letter kitni baar aaya hai.

# %%
text = "Welcome to coding"
text = text.count('o')
print(text)
# Out:
# 3

# %% [markdown]
# ### 8. User se unki age input lein aur usse integer mein convert karke print karein.

# %%
UserAge = int(input("Enter your age"))
print(type(UserAge))
# Out:
# Enter your age 19
# <class 'int'>

# %% [markdown]
# ### 9. Ek float value '15.99' ko integer mein convert karein. Output kya aaya?

# %%
value = int(float(15.99))
print(value)
# Out:
# 15

# %% [markdown]
# ### 10. Do numbers ko input lein, dono ko add karein, lekin dhayan rahe input hamesha string hota hai, isliye unhe cast karein.

# %%
num1 = int(input("Enter number one"))
num2 = int(input("Enter number two"))
print(num1 + num2)
# Out:
# Enter number one 6
# Enter number two 7
# 13

# %% [markdown]
# ### 11. Ek integer 100 ko string mein convert karein aur check karein ke uska type ab 'str' hai ya nahi.

# %%
num = str(100)
print(type(num))
# Out:
# <class 'str'>

# %% [markdown]
# ### 12. User se price lein (e.g., 99.5) aur usse integer mein badal kar dikhayein.

# %%
price = int(float(input("Enter price")))
print(price)
# Out:
# Enter price 99.5
# 99

# %% [markdown]
# ### 13. Ek string '10' aur doosri string '20' ko add (concatenate) karne ki jagah math wala addition (30) karke dikhayein.

# %%
num1 = int('10')
num2 = int('20')
print(num1 + num2)
# Out:
# 30

# %% [markdown]
# ### 14. Ek variable mein '50.5' save karein aur usse float mein cast karne ke baad 10 plus karein.

# %%
num = 50.5
num = float(num)
print(num + 10)
# Out:
# 60.5

# %% [markdown]
# ### 15. User se uska naam aur shehar (city) ka naam poochiye aur ek sentence print karein: 'Hello [Name], welcome to [City]'.

# %%
userName = input("your name?")
userCity = input("your city?")
print("Hello",userName,"welcome to",userCity)
# Out:
# your name? minhaj
# your city? karachi
# Hello minhaj welcome to karachi

# %% [markdown]
# ### 16. User se do numbers lein aur unka product (multiply) print karein.

# %%
num1 = int(input("Enter number one"))
num2 = int(input("Enter number two"))
print(num1 * num2)
# Out:
# Enter number one 7
# Enter number two 9
# 63

# %% [markdown]
# ### 17. User se unka favorite color poochiye aur print karein: 'I also like [color]'.

# %%
fav_color = input("Your Fav Color")
print('i also like',fav_color)
# Out:
# Your Fav Color yellow
# i also like yellow

# %% [markdown]
# ### 18. Ek chota program banayein jo user se uska birth year le aur uska current age calculate karein.

# %%
userBirthYear = int(input("enter your birth year"))
currentYear = int("2026")
age = currentYear - userBirthYear
print("Your age is",age)
# Out:
# enter your birth year 2006
# Your age is 20

# %% [markdown]
# ### 19. User se ek word input lein aur usse 5 baar print karein (string multiplication use karke).

# %%
user_word = input("enter any word")
user_word = user_word * 5
print(user_word)
# Out:
# enter any word apple
# appleappleappleappleapple

# %% [markdown]
# ### 20. User se unka mobile number lein (as string) aur unhe batayein ke unhone kya number type kiya hai.

# %%
user_num = input("enter your number")
print(f"aapne {user_num} type kia hai")
# Out:
# enter your number 457436
# aapne 457436 type kia hai

# %% [markdown]
# ### 21. Do variables lein a=10, b=3. Inka remainder (modulo) nikal kar dikhayein.

# %%
a = 10
b = 3
remainder = a % b
print(remainder)
# Out:
# 1

# %% [markdown]
# ### 22. Check karein ke 15, 10 se bada hai AUR 20 se chota hai (Logical AND operator).

# %%
(15>10)and(15<20)
# Out:
# True

# %% [markdown]
# ### 23. User se ek number lein aur check karein ke wo 100 se bada hai ya nahi (Comparison operator).

# %%
userNum = int(input("Enter number"))
(userNum>100)
# Out:
# Enter number 102
# True

# %% [markdown]
# ### 24. 2 ki power 5 (2^5) calculate karke print karein.

# %%
num = 2**5
print(num)
# Out:
# 32

# %% [markdown]
# ### 25. Check karein ke kya 50, 100 ke barabar hai (Equal to operator).

# %%
50==100
# Out:
# False

# %% [markdown]
# ### 26. Do Boolean values (True, False) lein aur 'OR' operator ka result dikhayein.

# %%
a = 4
b = 5
c = 4
a == b or c == b
# Out:
# False

# %% [markdown]
# ### 27. User se ek number lein aur check karein ke wo Positive hai ya Negative.

# %%
user_num = int(input("enter a number"))
if user_num>=0:
    print(f"{user_num} positive value hai")
else:
    print(f"{user_num} negative value hai")
# Out:
# enter a number -3837
# -3837 negative value hai

# %% [markdown]
# ### 28. Check karein ke user ki age 18 se zyada hai ya nahi, agar hai toh print 'Eligible for Vote'.

# %%
age = int(input("enter your age"))
if age>18:
    print("Eligible for Vote")
else:
    print("Not eligible for Vote")
# Out:
# enter your age 16
# Not eligible for Vote

# %% [markdown]
# ### 29. Ek number input lein aur check karein ke wo Even hai ya Odd.

# %%
num = int(input("enter your number"))
remainder = num%2
if remainder == 0:
    print(f"{num} is an even number")
else:
    print(f"{num} is an odd number")
# Out:
# enter your number 45
# 45 is an odd number

# %% [markdown]
# ### 30. User se do numbers lein aur batayein dono mein se bada (Greater) kaunsa hai.

# %%
num1 = int(input("enter your number"))
num2 = int(input("enter your number"))
if num1>num2:
    print(f"{num1} is greater than {num2}")
else:
    print(f"{num2} is greater than {num1}")
# Out:
# enter your number 65
# enter your number 98
# 98 is greater than 65

# %% [markdown]
# ### 31. Ek student ke marks input lein. Agar marks 33 se zyada hain toh 'Pass', warna 'Fail'.

# %%
student_marks = float(input("enter your marks"))
if student_marks>33:
    print("you are passed")
else:
    print("you are failed")
# Out:
# enter your marks 67
# you are passed

# %% [markdown]
# ### 32. Check karein ke user ne jo string input ki hai wo empty toh nahi hai.

# %%
username = input("enter your name")
if username == "":
    print("empty")
else:
    print("good")
# Out:
# enter your name
# empty

# %% [markdown]
# ### 33. User se ek password input lein. Agar password 'python123' hai toh 'Access Granted', warna 'Wrong Password'.

# %%
password = input("enter password")
correct_password = ("python123")
if password == correct_password:
    print("Access Granted")
else:
    print("Wrong Password")
# Out:
# enter password python123
# Access Granted

# %% [markdown]
# ### 34. Check karein ke user ka input kiya hua number zero hai ya nahi.

# %%
user_num = int(input("Enter your number"))
if user_num == 0:
    print(f"Your entered number is {user_num}")
else:
    print(f"{user_num}")
# Out:
# Enter your number 0
# Your entered number is 0

# %% [markdown]
# ### 35. Student Grading System: 90+ (A), 80-89 (B), 70-79 (C), below 70 (D).

# %%
student_per = int(input("Enter yor marks"))
if student_per>=90:
    grade = ("A grade")
elif student_per>=80:
    grade = ("B grade")
elif student_per>=70:
    grade = ("C grade")
else:
    grade = ("D grade")
print(f"Your Percentage is: {student_per}")
print(f"Your Grade is: {grade}")
# Out:
# Enter yor marks 50
# Your Percentage is: 50
# Your Grade is: D grade

# %% [markdown]
# ### 36. User se temperature lein. Agar 30 se zyada hai toh 'Hot', 15-30 hai toh 'Warm', 15 se niche hai toh 'Cold'.

# %%
# Write your code here
temperature = float(input("Enter Temperature"))
if temperature>30:
    print("it is hot today")
elif temperature>=15:
    print("it is warm today")
else:
    print("it is cold today")
# Out:
# Enter Temperature 12
# it is cold today

# %% [markdown]
# ### 37. Ek number check karein ke wo 3 se divisible hai, 5 se divisible hai, ya dono se (FizzBuzz logic).

# %%
# Write your code here
num = int(input("enter a number"))

if num%3==0 and num%5==0:
    print(f"number {num} is a divisible of both 3 and 5")
elif num%3==0:
    print(f"number {num} is a divisible of 3")
elif num%5==0:
    print(f"number {num} is a divisible of 5")
else:
    print(f"number {num} is not a divisible of 3 and 5")
# Out:
# enter a number 15
# number 15 is a divisible of both 3 and 5

# %% [markdown]
# ### 38. User se ek character lein aur check karein ke wo Vowel (a, e, i, o, u) hai ya Consonant.

# %%
# Write your code
character = input("enter a character")
vowel = ["a","e","i","o","u"]
if character==vowel[0]:
    print("it is a vowel")
elif character==vowel[1]:
    print("it is a vowel")
elif character==vowel[2]:
    print("it is a vowel")
elif character==vowel[3]:
    print("it is a vowel")
elif character==vowel[4]:
    print("it is a vowel")
else:
    print("it is consonant")
# Out:
# enter a character e
# it is a vowel

# %% [markdown]
# ### 39. Bill Calculator: Agar shopping 5000 se upar hai toh 20% discount, 2000-5000 par 10% discount, warna No discount.

# %%
# Write your code here
bill = int(input("Enter bill amaount"))
if bill>5000:
    discount = bill*.2
    total = bill - discount
elif bill>=2000:
    discount = bill*.1
    total = bill - discount
else:
    discount = bill*.0
    total = bill - discount

print(f"""
      your bill amount is {bill}
      your discount amount is {discount}
      your total bill amount is {total}""")

# %% [markdown]
# ### 40. Ek person ki age check karein: 0-12 (Child), 13-19 (Teenager), 20-59 (Adult), 60+ (Senior Citizen).

# %%
# Write your code here
age = int(input("Enter Your Age"))

if age<=12:
    print("child")
elif age<=19:
    print("teenager")
elif age<60:
    print("Adult")
else:
    print("senior citizen")
# Out:
# Enter Your Age 65
# senior citizen

# %% [markdown]
# ### 41. Check karein ke ek saal (year) Leap Year hai ya nahi.

# %%
# Write your code here
year = int(input("Enter a year"))
leap_year = year%4
if leap_year == 0:
    print(f"{year} is a leap year")
else:
    print(f"{year} is not a leap year")
# Out:
# Enter a year 2013
# 2013 is not a leap year

# %% [markdown]
# ### 42. User se week number (1-7) lein aur corresponding day (Monday, Tuesday...) print karein.

# %%
# Write your code here
week_number = int(input("Enter week number"))
week_days = ["monday","tuesday","wednesday","thursday","friday","saturday","sunday"]

if week_number==1:
    print(f"day number 1 in week: {week_days[0]}")
elif week_number==2:
    print(f"day number 2 in week: {week_days[1]}")
elif week_number==3:
    print(f"day number 3 in week: {week_days[2]}")
elif week_number==4:
    print(f"day number 4 in week: {week_days[3]}")
elif week_number==5:
    print(f"day number 5 in week: {week_days[4]}")
elif week_number==6:
    print(f"day number 6 in week: {week_days[5]}")
elif week_number==7:
    print(f"day number 7 in week: {week_days[6]}")
else:
    print("Invalid week number")
# Out:
# Enter week number 6
# day number 6 in week: saturday

# %% [markdown]
# ### 43. Ek simple calculator banayein (+, -, *, /) symbols ke basis par operation perform karein.

# %%
# Write your code here
num1 = int(input("Enter number"))
operator = input("Enter operator")
num2 = int(input("Enter number"))

if operator=="+":
    print(num1 + num2)
elif operator=="-":
    print(num1 - num2)
elif operator=="*":
    print(num1 * num2)
elif operator=="/":
    print(num1 / num2)
else:
    print("invalid operator")
# Out:
# Enter number 45
# Enter operator +
# Enter number 65
# 110

# %% [markdown]
# ### 44. User ka weight aur height le kar BMI category batayein (Underweight, Normal, Overweight).

# %%
# Write your code here
weight = float(input("Enter your weight in Kg"))
height = float(input("Enter your height in Meter"))
bmi = weight / (height**2)
bmi = round(bmi, 1)
print(f"your bmi is {bmi}")

if bmi<20:
    print("you are underweight")
elif bmi<25:
    print("you are normal")
elif bmi<30:
    print("you are overweight")
else:
    print("you are too much overweighted")
# Out:
# Enter your weight in Kg 65
# Enter your weight in Meter 1.9
# your bmi is 18.0
# you are underweight

# %% [markdown]
# ### 45. ATM Machine Logic: Pehle PIN check karein, agar sahi ho toh Amount poochiye, agar account balance se kam amount ho toh 'Withdrawal Success'.

# %%
# Write your code here
pin = int(input("Enter your pin"))
correct_pin = 13579
account_balance = 50000
if pin==correct_pin:
    amount = int(input("Enter your amount"))
    if amount<account_balance:
        print(f"""
        your account balance is: {account_balance}
        your withdrawal amount is: {amount}
        your remaining account balance is: {account_balance - amount}""")
    else:
        print("not enough money in account")
else:
    print("invalid pin")
# Out:
# Enter your pin 13579
# Enter your amount 45000
#         your account balance is: 50000
#         your withdrawal amount is: 45000
#         your remaining account balance is: 5000

# %% [markdown]
# ### 46. Login System: Pehle Username check karein, agar match ho tabhi Password check karein.

# %%
### Write your code here
user_name = input("enter username")
saved_user_name = "minhaj1243"
saved_password = "saylani321"

if user_name==saved_user_name:
    password = input("password")
    if password==saved_password:
        print("login successful")
    else:
        print(f"password: {password} is incorrect")
else:
    print(f"username: {user_name} is incorrect")
# Out:
# enter username minhaj1243
# password saylani321
# login successful

# %% [markdown]
# ### 47. Largest of Three: User se 3 numbers lein aur nested if-else use karke sabse bada number dhoondein.

# %%
# Write your code here
num1 = int(input("enter number"))
num2 = int(input("enter number"))
num3 = int(input("enter number"))

if num1>num2:
    if num1>num3:
        print(f"{num1} is largest")
if num2>num3:
    if num2>num1:
        print(f"{num2} is largest")
if num3>num1:
    if num3>num2:
        print(f"{num3} is largest")
# Out:
# enter number 4
# enter number 2

# %% [markdown]
# ### 48. Ticket Booking: Pehle age check karein. Agar 18+ hai toh check karein 'Do you have ID?'. Agar ID hai toh 'Ticket Issued'.

# %%
# Write your code here
age = int(input("Enter your age"))
if age>18:
    user_id = input("Do you have ID?")
    if user_id == 'yes':
        print("Congratulations! Ticket issued")
    else:
        print("sorry you dont have an ID")    
else:
    print(f"sorry your age is {age} so you are not 18+")
# Out:
# Enter your age 20
# Do you have ID? yes
# Congratulations! Ticket issued

# %% [markdown]
# ### 49. Admission System: Agar student ke marks 80+ hain, toh check karein unka interview clear hai ya nahi. Dono clear hone par 'Admission Done'.

# %%
# Write your code here
student_marks = float(input("Enter your marks"))
if student_marks>80:
    interview = input("is your interview cleared?")
    if interview == 'yes':
        print("Congratulations! Admission Done")
    else:
        print("sorry your interview is not cleared so admission is canceled")    
else:
    print("sorry your marks are not 80+ so admission is canceled")
# Out:
# Enter your marks 85
# is your interview cleared? yes
# Congratulations! Admission Done

# %% [markdown]
# ### 50. Number Range: Check karein number positive hai ya nahi. Agar positive hai, toh check karein wo 100 se bada hai ya chota.

# %%
# Write your code here
user_num = int(input("Enter your number"))
if user_num>0:
    if user_num>100:
        print(f"{user_num} is greater than 100")
    else:
        print(f"{user_num} is less than 100")    
else:
    print(f"{user_num} is negative")
# Out:
# Enter your number 156
# 156 is greater than 100

# %% [markdown]
# ### 51. Restaurant Order: Pehle Veg ya Non-Veg poochein. Veg mein Paneer ya Dal, Non-Veg mein Chicken ya Mutton ka option dein.

# %%
# Write your code here
res_order = input("Veg or Non-Veg")
if res_order == 'veg':
    veg_items = input("paneer or dal")
    if veg_items == "paneer":
        print("order successful")
    elif veg_items == "dal":
        print("order successful")    
    else:
        print("invalid choice! only paneer and dal is available")
    
elif res_order == 'non-veg':
    non_veg_items = input("chicken or mutton")
    if non_veg_items == 'chicken':
        print("order successful")
    elif non_veg_items == "mutton":
        print("order successful")   
    else:
        print("invalid choice! only chicken and mutton is available")
        
else:
    print("only veg or non veg")
# Out:
# Veg or Non-Veg veg
# paneer or dal dal
# order successful

# %% [markdown]
# ### 52. Ek number input lein aur check karein ke wo Single digit hai, Double digit ya Triple digit.

# %%
# Write your code here
user_num = int(input("Enter your number"))
if user_num>=1000:
    print(f"{user_num} is greater than triple digit and it is not asked in question")
elif user_num>=100:
    print(f"{user_num} is a triple digit number")
elif user_num>=10:
    print(f"{user_num} is a double digit number")
elif user_num>=0:
    print(f"{user_num} is a single digit number")
# Out:
# Enter your number 48
# 48 is a double digit number

# %% [markdown]
# ### 53. User se salary aur service years lein. Agar service 5 saal se zyada hai toh 5% bonus calculate karke final salary batayein.

# %%
# Write your code here
service_year = int(input("enter your service years"))
salary = int(input("enter your salary"))
if service_year > 5:
    bonus = salary*.05
    net_salary = salary + bonus
else:
    print("bonus is only applied if service years is more than 5")
    
print(f"""your salary is {salary}
    your bonus is {bonus}
    your net salary is {net_salary}""")
# Out:
# enter your service years 7
# enter your salary 65343
# your salary is 65343
#     your bonus is 3267.15
#     your net salary is 68610.15

# %% [markdown]
# ### 54. Ek triangle ki teen sides input lein aur batayein ke wo Equilateral, Isosceles ya Scalene hai.

# %%
# Write your code here

# %% [markdown]
# ### 55. Month name check karke batayein ke us month mein kitne days hote hain (Jan, Feb...).

# %%
# Write your code here
month = input("enter a month")

# %% [markdown]
# ### 56. Nested If-Else se check karein ke ek number Even hai aur 50 se bada hai, ya Even hai aur 50 se chota hai.

# %%
# Write your code here
user_num = int(input("enter your number"))
remainder = user_num%2
if remainder == 0:
    if user_num>50:
        print(f"{user_num} is an even number and greater than 50")
    else:
        print(f"{user_num} is an even number and less than 50")
else:
    print(f"{user_num} is an odd number")
# Out:
# enter your number 48
# 48 is an even number and less than 50

# %% [markdown]
# ### 57. Student Result: Maths aur Science dono mein 40+ hone chahiye pass hone ke liye. Agar ek mein kam hain toh batayein kaunsa subject weak hai.

# %%
# Write your code here
math_marks = int(input("enter math marks"))
science_marks = int(input("enter science marks"))

if math_marks<40:
    print("math is weak")
elif science_marks<40:
    print("science is weak")
else:
    print("you are passed")
# Out:
# enter math marks 34
# enter science marks 88
# math is weak

# %% [markdown]
# ### 58. Electricity Bill: Pehle 100 units free, next 100 units Rs 5/unit, uske baad Rs 10/unit.

# %%
# Write your code here
units = float(input("enter your units"))

if units<=100:
    bill = units*0
elif units<=300:
    bill = (units-100)*5
else:
    bill = (units-300)*10 + 200*5

print(f"your units is {units} and your bill is {bill}")
# Out:
# enter your units 370
# your units is 370.0 and your bill is 1700.0

# %% [markdown]
# ### 59. Game Level: Score 0-50 (Beginner), 51-100 (Intermediate). Agar Intermediate hai toh check karein user ne boss level par kiya hai ya nahi.

# %%
# Write your code here
game_level = int(input("Enter your game level"))

if game_level<=50:  
    print("beginner")
    
elif game_level<=100:
    boss_level = input("do you've cleared boss level?")
    if boss_level == 'yes':
        print("intermediate with boss level cleared")
    else:
        print("intermediate with boss level not cleared")
# Out:
# Enter your game level 57
# do you've cleared boss level? no
# intermediate with boss level not cleared

# %% [markdown]
# ### 60. Final Challenge: Ek mini-project logic banayein jisme user se Username, Password, aur ek Security Question poochein nested loops aur if-else ke saath.

# %%
# Write your code here
saved_username = 'm_minhaj7686'
saved_password = 'car92bike12'
security_answer = 'smit'

username = input("Enter Username")
if username == saved_username:
    password = input("Enter your password")
    if password == saved_password:
        security_question = input("what is your institute name")
        if security_question == security_answer:
            print("login successful")
        else:
            print(f"security answer: {security_question} is incorrect")
    else:
        print(f"password: {password} is incorrect")    
else:
    print(f"username: {username} is incorrect")
# Out:
# Enter Username mfj
# username: mfj is incorrect
